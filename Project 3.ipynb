# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
#Reading CSV Files
import numpy as np
import pandas as pd
basics = pd.read_csv(basics_url,sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep = '\t', low_memory=False)
ratings = pd.read_csv(ratings_url, sep = '\t', low_memory =False)

# %%
#Replacing null cells
ratings = ratings.replace({'\\N':np.nan})
akas = akas.replace({'\\N':np.nan})
basics = basics.replace({'\\N':np.nan})

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250301 entries, 0 to 1250300
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1250301 non-null  object
#  1   averageRating  1250301 non-null  float64
#  2   numVotes       1250301 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.6+ MB

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32166425 entries, 0 to 32166424
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 1.9+ GB

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8113907 entries, 1 to 8964036
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 619.0+ MB

# %%
basics = basics[basics['runtimeMinutes'].notna()]

# %%
basics['runtimeMinutes'].isnull().sum()
# Out:
# 0

# %%
basics = basics[basics['genres'].notna()]
basics['genres'].isnull().sum()
# Out:
# 0

# %%
basics['titleType'].value_counts()
# Out:
# tvEpisode       923578
# short           476670
# movie           275198
# video           138210
# tvSeries         73006
# tvMovie          55675
# tvSpecial        13648
# tvMiniSeries     11326
# tvShort           6962
# videoGame          278
# Name: titleType, dtype: int64

# %%
basics1 = basics[basics['titleType']=='movie']

# %%
basics1['titleType'].value_counts()
# Out:
# movie    275198
# Name: titleType, dtype: int64

# %%
basics1.head()
# Out:
#          tconst titleType                    primaryTitle  \
# 570   tt0000574     movie     The Story of the Kelly Gang
# 587   tt0000591     movie                The Prodigal Son
# 672   tt0000679     movie  The Fairylogue and Radio-Plays
# 1172  tt0001184     movie         Don Juan de Serrallonga
# 1273  tt0001285     movie               The Life of Moses
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 570      The Story of the Kelly Gang       0      1906     NaN             70
# 587                L'enfant prodigue       0      1907     NaN             90
# 672   The Fairylogue and Radio-Plays       0      1908     NaN            120
# 1172         Don Juan de Serrallonga       0      1910     NaN             58
# 1273               The Life of Moses       0      1909     NaN             50
#
#                           genres
# 570   Action,Adventure,Biography
# 587                        Drama
# 672            Adventure,Fantasy
# ...

# %%
basics1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275198 entries, 570 to 8963886
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          275198 non-null  object
#  1   titleType       275198 non-null  object
#  2   primaryTitle    275198 non-null  object
#  3   originalTitle   275198 non-null  object
#  4   isAdult         275198 non-null  object
#  5   startYear       271022 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  275198 non-null  object
#  8   genres          275198 non-null  object
# dtypes: object(9)
# memory usage: 21.0+ MB

# %%
basics1.head()
# Out:
#          tconst titleType                    primaryTitle  \
# 570   tt0000574     movie     The Story of the Kelly Gang
# 587   tt0000591     movie                The Prodigal Son
# 672   tt0000679     movie  The Fairylogue and Radio-Plays
# 1172  tt0001184     movie         Don Juan de Serrallonga
# 1273  tt0001285     movie               The Life of Moses
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 570      The Story of the Kelly Gang       0      1906     NaN             70
# 587                L'enfant prodigue       0      1907     NaN             90
# 672   The Fairylogue and Radio-Plays       0      1908     NaN            120
# 1172         Don Juan de Serrallonga       0      1910     NaN             58
# 1273               The Life of Moses       0      1909     NaN             50
#
#                           genres
# 570   Action,Adventure,Biography
# 587                        Drama
# 672            Adventure,Fantasy
# ...

# %%
basics1 = basics1[basics1['startYear'].notna()]
basics1['startYear'].isnull().sum()
# Out:
# 0

# %%
basics1['startYear'] = basics1['startYear'].astype(str).astype(int)

# %%
basics1.head()
# Out:
#          tconst titleType                    primaryTitle  \
# 570   tt0000574     movie     The Story of the Kelly Gang
# 587   tt0000591     movie                The Prodigal Son
# 672   tt0000679     movie  The Fairylogue and Radio-Plays
# 1172  tt0001184     movie         Don Juan de Serrallonga
# 1273  tt0001285     movie               The Life of Moses
#
#                        originalTitle isAdult  startYear endYear  \
# 570      The Story of the Kelly Gang       0       1906     NaN
# 587                L'enfant prodigue       0       1907     NaN
# 672   The Fairylogue and Radio-Plays       0       1908     NaN
# 1172         Don Juan de Serrallonga       0       1910     NaN
# 1273               The Life of Moses       0       1909     NaN
#
#      runtimeMinutes                      genres
# 570              70  Action,Adventure,Biography
# 587              90                       Drama
# 672             120           Adventure,Fantasy
# ...

# %%
basics2 = basics1[basics1['startYear']>2000]
basics2 = basics2[basics2['startYear']<2022]
basics2.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34805  tt0035423     movie                                     Kate & Leopold
# 61119  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67672  tt0069049     movie                         The Other Side of the Wind
# 77968  tt0079644     movie                                      November 1828
# 86806  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 34805                             Kate & Leopold       0       2001     NaN
# 61119  El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67672                 The Other Side of the Wind       0       2018     NaN
# 77968                              November 1828       0       2001     NaN
# 86806                          The Naked Monster       0       2005     NaN
#
# ...

# %%
is_documentary = basics2['genres'].str.contains('documentary',case=False)
basics2 = basics2[~is_documentary]

# %%
keepers =basics2['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34805      True
# 61119      True
# 67672      True
# 77968      True
# 86806      True
#            ...
# 8963709    True
# 8963718    True
# 8963757    True
# 8963802    True
# 8963886    True
# Name: tconst, Length: 133217, dtype: bool

# %%
basics2 = basics2[keepers]
basics2
# Out:
#             tconst titleType  \
# 34805    tt0035423     movie
# 61119    tt0062336     movie
# 67672    tt0069049     movie
# 77968    tt0079644     movie
# 86806    tt0088751     movie
# ...            ...       ...
# 8963709  tt9916170     movie
# 8963718  tt9916190     movie
# 8963757  tt9916270     movie
# 8963802  tt9916362     movie
# 8963886  tt9916538     movie
#
#                                               primaryTitle  \
# 34805                                       Kate & Leopold
# 61119    The Tango of the Widower and Its Distorting Mi...
# 67672                           The Other Side of the Wind
# 77968                                        November 1828
# 86806                                    The Naked Monster
# ...                                                    ...
# 8963709                                      The Rehearsal
# 8963718                                          Safeguard
# 8963757                           Il talento del calabrone
# ...

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
akas1 = akas[akas['region']=='US']
akas1.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
import os
os.makedirs('Data/',exist_ok=True)

# %%
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints']

# %%
basics2.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
akas1.to_csv("Data/title.akas.tsv.gz",compression = 'gzip',index = False)
ratings.to_csv("Data/title.ratings.tsv.gz",compression = 'gzip',index = False)

# %%
basics2 = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics2.head()

# %%
akas1 = pd.read_csv("Data/title.akas.tsv.gz", low_memory = False)
akas1.head()

# %%
ratings = pd.read_csv("Data/title.ratings.tsv.gz", low_memory = False)
ratings.head()
