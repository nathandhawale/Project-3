# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
f0 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
f0.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
# 2  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
# 3  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
# 4  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
#
#                                belongs_to_collection      budget  \
# 0                                                NaN         NaN
# 1  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 2  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 3  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 4  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
#
#                                               genres  \
# 0                                                NaN
# 1  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...

# %%
f1 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory = False)
f1.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
# 2  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
# 3  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
# 4  tt0133093    0.0  /ncEsesgOJDNrTUED89hYbA117wo.jpg
#
#                                belongs_to_collection      budget  \
# 0                                                NaN         NaN
# 1  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 2  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 3  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 4  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
#
#                                               genres  \
# 0                                                NaN
# 1  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...

# %%
frames = [f0, f1]
f2 = pd.concat(frames)
f2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5624 entries, 0 to 2831
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                5624 non-null   object
#  1   adult                  5622 non-null   float64
#  2   backdrop_path          5622 non-null   object
#  3   belongs_to_collection  5622 non-null   object
#  4   budget                 5622 non-null   float64
#  5   genres                 5622 non-null   object
#  6   homepage               5622 non-null   object
#  7   id                     5622 non-null   float64
#  8   original_language      5622 non-null   object
#  9   original_title         5622 non-null   object
#  10  overview               5622 non-null   object
#  11  popularity             5622 non-null   float64
#  12  poster_path            5622 non-null   object
#  13  production_companies   5622 non-null   object
# ...

# %%
f2['revenue'].value_counts()
# Out:
# 463517383.0    5622
# Name: revenue, dtype: int64

# %%
f2['certification'].value_counts()
#I do not know what happened here, but I know how to plot it
# Out:
# R    5622
# Name: certification, dtype: int64

# %%
f2["certification"].value_counts().plot.bar()

plt.show()

# %%
f2['revenue'].mean()
# Out:
# 463517383.0

# %%
f2['budget'].mean()
# Out:
# 63000000.0
